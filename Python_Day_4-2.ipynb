# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %% [markdown]
# # Upload CSV file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e6a3407f-f801-403e-8827-ce378729f26c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6a3407f-f801-403e-8827-ce378729f26c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Create a dataframe from the CSV file

# %%
df = pd.read_csv('capita.csv')  # load data from a file into a DataFrame
df  # display the Dataframe
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0             1            Monaco    Europe             0         0
# 1             2     Liechtenstein    Europe             0         0
# 2             3        Luxembourg    Europe        132372      2023
# 3             4           Ireland    Europe        114581      2023
# 4             5           Bermuda  Americas             0         0
# ..          ...               ...       ...           ...       ...
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0                234316            2021       234317    2021
# ...

# %% [markdown]
# # Print the first 10 rows

# %%
df.head(10)  # preview the first 10 rows
# Out:
#    Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0           1            Monaco    Europe             0         0
# 1           2     Liechtenstein    Europe             0         0
# 2           3        Luxembourg    Europe        132372      2023
# 3           4           Ireland    Europe        114581      2023
# 4           5           Bermuda  Americas             0         0
# 5           6            Norway    Europe        101103      2023
# 6           7       Switzerland    Europe         98767      2023
# 7           8         Singapore      Asia         91100      2023
# 8           9       Isle of Man    Europe             0         0
# 9          10    Cayman Islands  Americas             0         0
#
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0              234316            2021       234317    2021
# 1              157755            2020       169260    2021
# 2              133590            2021       133745    2021
# ...

# %% [markdown]
# # Print the last 5 rows

# %%
df.tail(5)  # preview the last 5 rows
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 218                 635            2021          613    2021
# 219                1072            2015          400    2021
# 220                 480            2021          505    2021
# 221                 369            2021          373    2021
# 222                 222            2021          311    2021

# %% [markdown]
# # Print ‘Country/Territory’ and ‘UN_Region’ columns

# %%
# Creating a varaible to store the filtered data
country_and_region = df[['Country/Territory', 'UN_Region']]
country_and_region
# Out:
#     Country/Territory UN_Region
# 0              Monaco    Europe
# 1       Liechtenstein    Europe
# 2          Luxembourg    Europe
# 3             Ireland    Europe
# 4             Bermuda  Americas
# ..                ...       ...
# 218            Malawi    Africa
# 219       South Sudan    Africa
# 220      Sierra Leone    Africa
# 221       Afghanistan      Asia
# 222           Burundi    Africa
#
# [223 rows x 2 columns]

# %% [markdown]
# # Check Missing Values

# %%
df.isnull()
# Out:
#      Unnamed: 0  Country/Territory  UN_Region  IMF_Estimate  IMF_Year  \
# 0         False              False      False         False     False
# 1         False              False      False         False     False
# 2         False              False      False         False     False
# 3         False              False      False         False     False
# 4         False              False      False         False     False
# ..          ...                ...        ...           ...       ...
# 218       False              False      False         False     False
# 219       False              False      False         False     False
# 220       False              False      False         False     False
# 221       False              False      False         False     False
# 222       False              False      False         False     False
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate  UN_Year
# 0                 False           False        False    False
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Check If Not Any Missing Values

# %%
df.notnull()
# Out:
#      Unnamed: 0  Country/Territory  UN_Region  IMF_Estimate  IMF_Year  \
# 0          True               True       True          True      True
# 1          True               True       True          True      True
# 2          True               True       True          True      True
# 3          True               True       True          True      True
# 4          True               True       True          True      True
# ..          ...                ...        ...           ...       ...
# 218        True               True       True          True      True
# 219        True               True       True          True      True
# 220        True               True       True          True      True
# 221        True               True       True          True      True
# 222        True               True       True          True      True
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate  UN_Year
# 0                  True            True         True     True
# ...

# %% [markdown]
# # Check For Any Missing Values In Any Column or Row

# %%
df.isnull().values.any()
# Out:
# np.False_

# %% [markdown]
# # Check For Any Missing Values In Any Rows

# %%
df.isnull().values.any(axis=1)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %% [markdown]
# # Check Total Missing Values In Each Column

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Country/Territory     0
# UN_Region             0
# IMF_Estimate          0
# IMF_Year              0
# WorldBank_Estimate    0
# WorldBank_Year        0
# UN_Estimate           0
# UN_Year               0
# dtype: int64

# %% [markdown]
# # Check Total Missing Values In DataFrame

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Convert Date to DateTime Format

# %%
df['IMF_Year'] = pd.to_datetime(df['IMF_Year'], format='%Y', errors='coerce')

# %% [markdown]
# # Remove Whitespace In Text Data (Trim / Strip)

# %%
df['Country/Territory'] = df['Country/Territory'].str.strip()

# %% [markdown]
# # Convert Data Types

# %%
  # - tidy or transform columns
df['WorldBank_Estimate'] = pd.to_numeric(df['WorldBank_Estimate'], errors='coerce').fillna(0).astype(int)  # change the data type (e.g., text to number)

# %% [markdown]
# # **Visualisation** 📊

# %% [markdown]
# # Create Histogram Using Pandas

# %%
df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'IMF_Estimate'}>],
#        [<Axes: title={'center': 'IMF_Year'}>,
#         <Axes: title={'center': 'WorldBank_Estimate'}>],
#        [<Axes: title={'center': 'WorldBank_Year'}>,
#         <Axes: title={'center': 'UN_Estimate'}>]], dtype=object)

# %% [markdown]
# # Import MatPlotLib and Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Select only the numerical features for correlation analysis

# %%
numerical_features = df.select_dtypes(include=['number'])

# %% [markdown]
# # Calculate a Correlation Matrix

# %%
corr = numerical_features.corr()

# %% [markdown]
# # Plot a Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='GnBu')
plt.show()

# %% [markdown]
# # Plot a Barplot

# %%
fig = plt.figure(figsize=(8, 5))
sns.barplot(x="IMF_Estimate", y="UN_Region", data=df, ci=None)
plt.show()
# Out:
# /tmp/ipython-input-2253373039.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="IMF_Estimate", y="UN_Region", data=df, ci=None)

# %% [markdown]
# # Plot a Scattter Chart

# %%
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter', figsize=(10, 6), title="scatter")
# Out:
# <Axes: title={'center': 'scatter'}, xlabel='UN_Region', ylabel='UN_Estimate'>

# %% [markdown]
# # Plot a Bar Chat

# %%
ax = sns.countplot(x="UN_Region", data=df[-(df.UN_Region=="World")])
ax.bar_label(ax.containers[0])

plt.title("  # of Countries")
plt.show()
