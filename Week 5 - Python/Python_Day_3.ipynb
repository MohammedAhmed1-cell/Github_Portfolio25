# %% [markdown]
# # Install pandas library

# %%
pip install pandas

# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Demo dataframe setup

# %%
# Create a dictionary to store the data we will generate the dataframe from
data = {
    "calories": [420, 380, 390],
    "duration": [50, 40, 45]
}

# create the dataframe variable and generate it using pandas dataframe function
df = pd.DataFrame(data)

# print dataframe
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# # Upload csv file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e0678bb-e340-4c14-89a7-2289ab3b6aad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e0678bb-e340-4c14-89a7-2289ab3b6aad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Create a dataframe from the csv file

# %%
dataframe = pd.read_csv('student.csv')
dataframe
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %% [markdown]
# # Subsetting the dataframe

# %%
# Select a singular column
dataframe['gender']

# Select multiple columns
dataframe[['name','gender','class']]
# Out:
#            name  gender  class
# 0      John Deo  female   Four
# 1      Max Ruin    male  Three
# 2        Arnold    male  Three
# 3    Krish Star  female   Four
# 4     John Mike  female   Four
# 5     Alex John    male   Four
# 6   My John Rob    male  Fifth
# 7        Asruid    male   Five
# 8       Tes Qry     NaN    Six
# 9      Big John  female   Four
# 10       Ronald  female    Six
# 11        Recky  female    Six
# 12          Kty  female  Seven
# 13         Bigy  female  Seven
# 14     Tade Row    male    NaN
# 15        Gimmy    male   Four
# 16        Tumyu    male    Six
# 17        Honny    male   Five
# 18        Tinny    male   Nine
# 19       Jackly  female   Nine
# 20   Babby John  female   Four
# 21       Reggid  female  Seven
# 22        Herod    male  Eight
# 23    Tiddy Now    male  Seven
# 24     Giff Tow    male  Seven
# 25       Crelea    male  Seven
# 26          NaN     NaN  Three
# 27    Rojj Base  female  Seven
# 28  Tess Played    male  Seven
# ...

# %% [markdown]
# Locating data

# %%
# head() will by default return the first 5 rows - we can pass a number as an argument
# dataframe.head()

# We can create variable to score the iloc (location) of a particular row of data
#row_2_data = dataframe.iloc[1]
#row_2_data

# Selecting dat afrom our dataframe - using a slice to selct which rows we want and which coloums
# REMEMBER SLICES are NOT endpoint inclusive, so 0:2 will pull rows 0 and 1
subset_dataframe = dataframe.iloc[0:2, 1:2]
subset_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-918473315.py in <cell line: 0>()
#       9 # REMEMBER SLICES are NOT endpoint inclusive, so 0:2 will pull rows 0 and 1
#      10 subset_dataframe = dataframe.iloc[0:2, 1:2]
# ---> 11 subset_data
#
# NameError: name 'subset_data' is not defined

# %% [markdown]
# # Filter the Dataframe

# %%
# Filter based or a single criteria
#dataframe[dataframe['mark']>70]

# Filter based on astring value - NOTE with this string would need to be an exact match
#dataframe[dataframe['name'] == 'Max Ruin']

# Filter based on 2 criteria (this & this)
#dataframe[(dataframe['mark'] > 60) & (dataframe['mark'] < 80)]

# Filter based on 2 criteria (this or this)
#dataframe[(dataframe['mark'] < 60) | (dataframe['mark'] > 80)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-715591737.py in <cell line: 0>()
#       2 #dataframe[dataframe['mark']>70]
#       3 #dataframe[dataframe['name'] == 'Max Ruin']
# ----> 4 dataframe[dataframe['name'].str.contains('Max')]
#       5
#       6 # Filter based on 2 criteria (this & this)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
# -> 4092         if com.is_bool_indexer(key):
#    4093             return self._getitem_bool_array(key)
#    4094
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     134                     # Don't raise on e.g. ["A", "B", np.nan], see
#     135                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# ...

# %% [markdown]
# # Inspecting a dataframe

# %%
# First 5 rows or specified amount of rows from the top
#dataframe.head()
#dataframe.head(10)

# Last 5 rows or specified amount of rows in the bottom
#dataframe.tail()
#dataframe.tail(10)

# Check the dimensions of our dataframe - (35 is rows, 5 is colums. (35, 5))
#dataframe.shape

# Check for missing values
#dataframe.isnull().sum()

# Check for missing values - totals
#dataframe.isnull().sum().sum()

# Data types columns
#dataframe.dtypes

# Information on df - data types, non-null etc
#dataframe.info()

# Columns names in dataframe
#dataframe.colums

# Renaming a column
#dataframe.rename(columns={'class': 'group'}, inplace=True)
#dataframe.columns

# Dropping all rows that have null values
#dataframe.dropna()

# Count unique values in a column
#dataframe['gender'].value_counts()
# Out:
# gender
# male      17
# female    16
# Name: count, dtype: int64

# %% [markdown]
# # Summary functions

# %%
# Summary stats
#dataframe.describe()

# Mean - if you are looking to specify by column, follow "dataframe" / "df" with a column ['name']
dataframe['id'].mean()
# Out:
# np.float64(18.0)

# %% [markdown]
# Day 3: Task 1
#
# Using the ‘student.csv’ which can be downloaded here, complete the below exercises as a group and paste your input and output. Although this is a group activity, everyone should have the below answered so it supports your portfolio:

# %% [markdown]
# Exercise 1: Loading and Exploring the Data
#
# Question 1: "Write the code to read a CSV file into a Pandas DataFrame."
#
# Question 2: "Write the code to display the first 5 rows of the DataFrame."
#
# Question 3: "Write the code to get the information about the DataFrame."
#
# Question 4: "Write the code to get summary statistics for the DataFrame."

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5da79641-a8a5-4a73-bb8c-fc3a289b79a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5da79641-a8a5-4a73-bb8c-fc3a289b79a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display first 5 rows
dataframe.head()
# Out:
#    id        name  group  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
# Display basic info about the DataFrame
# Display info about the DataFrame
print(dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   group   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB
# None

# %%
# Display statistical summary of numerical columns
# Display summary statistics
print(dataframe.describe())
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %% [markdown]
# EX 2

# %%
# Select the 'name' column
dataframe['name']
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
# Select the 'name' and 'mark' columns
dataframe[['name', 'mark']]
# Out:
#            name  mark
# 0      John Deo    75
# 1      Max Ruin    85
# 2        Arnold    55
# 3    Krish Star    60
# 4     John Mike    60
# 5     Alex John    55
# 6   My John Rob    78
# 7        Asruid    85
# 8       Tes Qry    78
# 9      Big John    55
# 10       Ronald    89
# 11        Recky    94
# 12          Kty    88
# 13         Bigy    88
# 14     Tade Row    88
# 15        Gimmy    88
# 16        Tumyu    54
# 17        Honny    75
# 18        Tinny    18
# 19       Jackly    65
# 20   Babby John    69
# 21       Reggid    55
# 22        Herod    79
# 23    Tiddy Now    78
# 24     Giff Tow    88
# 25       Crelea    79
# 26          NaN    81
# 27    Rojj Base    86
# 28  Tess Played    55
# 29    Reppy Red    79
# 30  Marry Toeey    88
# 31    Binn Rott    90
# 32    Kenn Rein    96
# 33     Gain Toe    69
# 34   Rows Noump    88

# %%
# Select the first 3 rows
dataframe.head(3)
# Out:
#    id      name  group  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
# Select all rows where 'class' is 'Four'
dataframe[dataframe['class'] == 'Four']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2763691564.py in <cell line: 0>()
#       1 # Select all rows where 'class' is 'Four'
# ...

# %% [markdown]
# # EX 3

# %%
# Add a new column 'passed'
dataframe['passed'] = dataframe['mark'] >= 60
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mark'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3486625251.py in <cell line: 0>()
#       1 # Add a new column 'passed'
# ...

# %%
# Rename the column
dataframe.rename(columns={'mark': 'score'}, inplace=True)

# %%
# Drop the 'passed' column
dataframe.drop(columns=['passed'], inplace=True)

# %% [markdown]
# # EX 4

# %%
# Group by 'class' and calculate mean 'mark'
mean_marks_by_class = dataframe.groupby('class')['mark'].mean()
print(mean_marks_by_class)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1729673957.py in <cell line: 0>()
#       1 # Group by 'class' and calculate mean 'mark'
# ----> 2 mean_marks_by_class = dataframe.groupby('class')['mark'].mean()
#       3 print(mean_marks_by_class)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
# Count number of students in each class
dataframe['class'].value_counts()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64

# %%
# Group by 'gender' and calculate the mean 'mark'
average_mark_by_gender = df.groupby('gender')['mark'].mean()
print(average_mark_by_gender)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4105837512.py in <cell line: 0>()
#       1 # Group by 'gender' and calculate the mean 'mark'
# ----> 2 average_mark_by_gender = df.groupby('gender')['mark'].mean()
#       3 print(average_mark_by_gender)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
# ...

# %% [markdown]
# # EX 5

# %%
# Create a pivot table
pd.pivot_table(dataframe, values='mark', index='class', columns='gender', aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3963335952.py in <cell line: 0>()
#       1 # Create a pivot table
# ----> 2 pd.pivot_table(dataframe, values='mark', index='class', columns='gender', aggfunc='mean')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     100         return table.__finalize__(data, method="pivot_table")
#     101
# --> 102     table = __internal_pivot_table(
#     103         data,
#     104         values,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     170
#     171     observed_bool = False if observed is lib.no_default else observed
# ...

# %%
# Create a new 'grade' column using conditions
df['grade'] = pd.cut(
    df['mark'],
    bins=[0, 59, 69, 84, 100],
    labels=['D', 'C', 'B', 'A']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mark'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-435499259.py in <cell line: 0>()
#       1 # Create a new 'grade' column using conditions
# ...

# %%
# Sort by 'mark' in descending order
df.sort_values(by='mark', ascending=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-998817541.py in <cell line: 0>()
#       1 # Sort by 'mark' in descending order
# ----> 2 df.sort_values(by='mark', ascending=False, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# ...

# %% [markdown]
# # EX 6

# %%
# Save the updated DataFrame to a new CSV file
df.to_csv('student_with_grades.csv', index=False)

# %% [markdown]
# # EX 7
